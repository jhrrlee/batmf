# %%
"""
RUL_ML_Framework
File Name: feature_gen.ipynb

Description: data cleansing and feature generation

Author: junghwan lee

Email: jhrrlee@gmail.com
Date Created: 2023.09.07

"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.preprocessing import MinMaxScaler
from scipy import interpolate
import pickle
import itertools
import math
import cleansing_lib as cl
import importlib

# %%
importlib.reload(cl)

# %%
from pathlib import Path
data_path = Path('..') / 'battery_data' / 'mit'
gen_path = Path('..') / 'resource' / 'dataset'

battery_data_path = data_path / 'bat_dict.pkl'
eol_path = gen_path / 'eol.npy'
cycle_data_dis_path = gen_path / 'cycle_data_dis.npy'
cycle_data_ch_path = gen_path / 'cycle_data_ch.npy'
new_cycle_sum_path = gen_path / 'new_cycle_sum.npy'

# %%
ith open(battery_data_path, 'rb') as f:
    bat_dict = pickle.load(f)

# %%
bat_dict.keys()
# Out:
# dict_keys(['b1c0', 'b1c1', 'b1c2', 'b1c3', 'b1c4', 'b1c5', 'b1c6', 'b1c7', 'b1c9', 'b1c11', 'b1c14', 'b1c15', 'b1c16', 'b1c17', 'b1c18', 'b1c19', 'b1c20', 'b1c21', 'b1c23', 'b1c24', 'b1c25', 'b1c26', 'b1c27', 'b1c28', 'b1c29', 'b1c30', 'b1c31', 'b1c32', 'b1c33', 'b1c34', 'b1c35', 'b1c36', 'b1c37', 'b1c38', 'b1c39', 'b1c40', 'b1c41', 'b1c42', 'b1c43', 'b1c44', 'b1c45', 'b2c0', 'b2c1', 'b2c2', 'b2c3', 'b2c4', 'b2c5', 'b2c6', 'b2c10', 'b2c11', 'b2c12', 'b2c13', 'b2c14', 'b2c17', 'b2c18', 'b2c19', 'b2c20', 'b2c21', 'b2c22', 'b2c23', 'b2c24', 'b2c25', 'b2c26', 'b2c27', 'b2c28', 'b2c29', 'b2c30', 'b2c31', 'b2c32', 'b2c33', 'b2c34', 'b2c35', 'b2c36', 'b2c37', 'b2c38', 'b2c39', 'b2c40', 'b2c41', 'b2c42', 'b2c43', 'b2c44', 'b2c45', 'b2c46', 'b2c47', 'b3c0', 'b3c1', 'b3c3', 'b3c4', 'b3c5', 'b3c6', 'b3c7', 'b3c8', 'b3c9', 'b3c10', 'b3c11', 'b3c12', 'b3c13', 'b3c14', 'b3c15', 'b3c16', 'b3c17', 'b3c18', 'b3c19', 'b3c20', 'b3c21', 'b3c22', 'b3c24', 'b3c25', 'b3c26', 'b3c27', 'b3c28', 'b3c29', 'b3c30', 'b3c31', 'b3c33', 'b3c34', 'b3c35', 'b3c36', 'b3c38', 'b3c39', 'b3c40', 'b3c41', 'b3c44', 'b3c45'])

# %%
# {'I': I, 'Qc': Qc, 'Qd': Qd, 'Qdlin': Qdlin, 'T': T, 'Tdlin': Tdlin, 'V':V, 'dQdV': dQdV, 't':t}

# %% [markdown]
# This function is designed to visualize battery charge and discharge data and apply basic cleansing logic to identify accurate start and end points for the discharging phase.
#
# Parameters:
# bat_dict: A nested dictionary containing battery data. Each key represents a cell, and its value is another dictionary with cycle data and summary data.
#
# cell_key: A string indicating the specific battery cell to be analyzed.
#
# cycle_key: A string indicating the specific cycle of the battery cell to be analyzed.
#
# max_gap (dQd/dt): An integer. It is the maximum allowable difference between consecutive indices in the discharge start determination logic. This helps to filter out noise or small fluctuations in the data and identify a reliable start point for the discharging phase. If the difference between indices exceeds this value, it will not be considered as a valid discharge start point.
#
# validation_range: An integer. It defines the length of the sequence of indices being checked for consistent gaps when determining the start of the discharging phase. It's essentially the window size over which we're looking for consecutive or near-consecutive indices. A larger value means a stricter criterion, ensuring that the start point selected is consistent over a longer range.
#
# Description:
# The battery's discharging phase is identified by an increase in the Qd (discharge capacity) value. However, to ensure the identified start of the discharging phase isn't due to noise or minor fluctuations, the function applies a heuristic:
#
# Look for points where the difference in Qd is positive (indicating a potential start of discharge).
#
# From these points, identify sequences where the difference between consecutive indices (gaps) are all smaller than the max_gap value.
#
# The validation_range parameter ensures that this consistent sequence of gaps is observed over a specified range, adding an extra layer of validation.
# Verification both data and cleasing code

# %%
cl.plot_cleansed_cycle(cl.get_cycle_data(bat_dict, 'b1c9'), '1', ch_current_threshold=0, validation_range=20, max_gap=20)

# %% [markdown]
# This function is more advanced for debugging of data cleasing with logs and plots. </br>
# to verify multiple cycle

# %%
cl.plot_cleansed_cycles(get_cycle_data(bat_dict, 'b1c9'), 1, 1000)
# Out:
#  89%|████████▉ | 888/1000 [00:36<00:11, 10.07it/s]
# remove cycle from time 886
# 1001it [00:43, 23.13it/s]

# %% [markdown]
# This function generates interpolated data for a complete cycle (charging, discharging cycle)

# %%
no_of_features = 8
no_of_cycles = 100
max_data_size = 1000
no_of_timeseries = 1000
cycle_start = 1

eol, cleaned_cycle_data = cl.get_inp_cycles(bat_dict, cycle_start, no_of_cycles, max_data_size, no_of_timeseries)

# %%
cleaned_cycle_data=np.array(cleaned_cycle_data).reshape(-1,no_of_cycles,no_of_features,no_of_timeseries) #(number of cell, first n cycle, property, time-series data)
eol=np.array(eol).reshape(-1,1)

# %%
print(eol.shape, cleaned_cycle_data.shape)
# Out:
# (124, 1) (124, 100, 8, 1000)

# %% [markdown]
# Regardless of time, features are alinged with index

# %%
cl.plot_inp_cycles(cleaned_cycle_data, cell_idx=0)

# %% [markdown]
# This function is used in my paper to make statistical data from current and temperature. </br>
# Abnormal cells are detected </br>
# Abnormal cycles are removed </br>
# With parameter changes, user will have different cleansed dataset.
# </br>
# ch_current_threshold=0.01 </br>
# validation_range=20,  </br>
# max_gap=20, </br>
# max_time=100 </br>

# %%
no_of_features = 5
no_of_cycles = 100
max_data_size = 1000
no_of_timeseries = 500
cycle_start = 1

eol, cycle_data_dis, cycle_data_ch = cl.get_cleaned_cycles(bat_dict, cycle_start, no_of_cycles, max_data_size, no_of_timeseries)
# Out:
# remove cycle 11 from time for cell b1c0
# remove cycle 11 from time for cell b1c1
# remove cycle 11 from time for cell b1c2
# remove cycle 11 from time for cell b1c3
# remove cycle 11 from time for cell b1c4
# remove cycle 12 from time for cell b1c5
# remove cycle 12 from time for cell b1c6
# remove cycle 12 from time for cell b1c7
# remove cycle 11 from time for cell b1c11
# remove cycle 12 from time for cell b1c14
# remove cycle 12 from time for cell b1c15
# remove cycle 12 from time for cell b1c16
# remove cycle 1 from time for cell b1c18
# remove cycle 2 from time for cell b1c18
# remove cycle 3 from time for cell b1c18
# remove cycle 4 from time for cell b1c18
# remove cycle 5 from time for cell b1c18
# remove cycle 6 from time for cell b1c18
# remove cycle 7 from time for cell b1c18
# remove cycle 8 from time for cell b1c18
# remove cycle 9 from time for cell b1c18
# remove cycle 10 from time for cell b1c18
# remove cycle 11 from time for cell b1c18
# remove cycle 12 from time for cell b1c18
# remove cycle 13 from time for cell b1c18
# remove cycle 14 from time for cell b1c18
# remove cycle 15 from time for cell b1c18
# remove cycle 16 from time for cell b1c18
# remove cycle 17 from time for cell b1c18
# remove cycle 18 from time for cell b1c18
# remove cycle 19 from time for cell b1c18
# remove cycle 20 from time for cell b1c18
# remove cycle 21 from time for cell b1c18
# remove cycle 22 from time for cell b1c18
# remove cycle 23 from time for cell b1c18
# remove cycle 24 from time for cell b1c18
# remove cycle 25 from time for cell b1c18
# remove cycle 26 from time for cell b1c18
# remove cycle 27 from time for cell b1c18
# remove cycle 28 from time for cell b1c18
# remove cycle 29 from time for cell b1c18
# remove cycle 30 from time for cell b1c18
# remove cycle 31 from time for cell b1c18
# remove cycle 32 from time for cell b1c18
# remove cycle 33 from time for cell b1c18
# remove cycle 34 from time for cell b1c18
# remove cycle 35 from time for cell b1c18
# remove cycle 36 from time for cell b1c18
# remove cycle 37 from time for cell b1c18
# remove cycle 38 from time for cell b1c18
# remove cycle 39 from time for cell b1c18
# remove cycle 40 from time for cell b1c18
# remove cycle 41 from time for cell b1c18
# remove cycle 42 from time for cell b1c18
# remove cycle 43 from time for cell b1c18
# remove cycle 44 from time for cell b1c18
# remove cycle 45 from time for cell b1c18
# remove cycle 46 from time for cell b1c18
# remove cycle 47 from time for cell b1c18
# remove cycle 48 from time for cell b1c18
# remove cycle 49 from time for cell b1c18
# remove cycle 50 from time for cell b1c18
# remove cycle 51 from time for cell b1c18
# remove cycle 52 from time for cell b1c18
# remove cycle 12 from time for cell b1c20
# remove cycle 12 from time for cell b1c21
# Cycle 1 for cell b2c3 exceeds max_data_size in charge with data_size 1027
# Cycle 2 for cell b2c3 exceeds max_data_size in charge with data_size 1034
# Cycle 3 for cell b2c3 exceeds max_data_size in charge with data_size 1048
# Cycle 4 for cell b2c3 exceeds max_data_size in charge with data_size 1018
# Cycle 13 for cell b2c3 exceeds max_data_size in charge with data_size 1432
# Cycle 14 for cell b2c3 exceeds max_data_size in charge with data_size 1028
# Cycle 15 for cell b2c3 exceeds max_data_size in charge with data_size 1088
# Cycle 16 for cell b2c3 exceeds max_data_size in charge with data_size 1042
# Cycle 18 for cell b2c3 exceeds max_data_size in charge with data_size 1063
# Cycle 25 for cell b2c3 exceeds max_data_size in charge with data_size 3393
# Cycle 26 for cell b2c3 exceeds max_data_size in charge with data_size 4506
# Cycle 27 for cell b2c3 exceeds max_data_size in charge with data_size 4193
# Cycle 28 for cell b2c3 exceeds max_data_size in charge with data_size 2270
# Cycle 29 for cell b2c3 exceeds max_data_size in charge with data_size 1538
# Cycle 30 for cell b2c3 exceeds max_data_size in charge with data_size 2218
# Cycle 31 for cell b2c3 exceeds max_data_size in charge with data_size 2513
# Cycle 32 for cell b2c3 exceeds max_data_size in charge with data_size 1451
# Cycle 33 for cell b2c3 exceeds max_data_size in charge with data_size 1268
# Cycle 34 for cell b2c3 exceeds max_data_size in charge with data_size 1095
# Cycle 35 for cell b2c3 exceeds max_data_size in charge with data_size 1781
# Cycle 36 for cell b2c3 exceeds max_data_size in charge with data_size 1152
# Cycle 37 for cell b2c3 exceeds max_data_size in charge with data_size 1159
# Cycle 39 for cell b2c3 exceeds max_data_size in charge with data_size 1176
# Cycle 40 for cell b2c3 exceeds max_data_size in charge with data_size 1165
# Cycle 41 for cell b2c3 exceeds max_data_size in charge with data_size 1165
# Cycle 42 for cell b2c3 exceeds max_data_size in charge with data_size 1179
# Cycle 43 for cell b2c3 exceeds max_data_size in charge with data_size 1013
# Cycle 44 for cell b2c3 exceeds max_data_size in charge with data_size 1033
# Cycle 45 for cell b2c3 exceeds max_data_size in charge with data_size 1170
# Cycle 46 for cell b2c3 exceeds max_data_size in charge with data_size 1060
# Cycle 48 for cell b2c3 exceeds max_data_size in charge with data_size 1013
# Cycle 49 for cell b2c3 exceeds max_data_size in charge with data_size 1023
# Cycle 69 for cell b2c3 exceeds max_data_size in charge with data_size 1105
# Cycle 73 for cell b2c3 exceeds max_data_size in charge with data_size 1064
# Cycle 74 for cell b2c3 exceeds max_data_size in charge with data_size 1094
# Cycle 75 for cell b2c3 exceeds max_data_size in charge with data_size 1085
# Cycle 76 for cell b2c3 exceeds max_data_size in charge with data_size 1084
# Cycle 77 for cell b2c3 exceeds max_data_size in charge with data_size 1019
# Cycle 78 for cell b2c3 exceeds max_data_size in charge with data_size 1132
# Cycle 79 for cell b2c3 exceeds max_data_size in charge with data_size 1023
# Cycle 80 for cell b2c3 exceeds max_data_size in charge with data_size 1066
# Cycle 81 for cell b2c3 exceeds max_data_size in charge with data_size 1168
# Cycle 82 for cell b2c3 exceeds max_data_size in charge with data_size 1238
# Cycle 83 for cell b2c3 exceeds max_data_size in charge with data_size 1224
# Cycle 84 for cell b2c3 exceeds max_data_size in charge with data_size 1131
# Cycle 85 for cell b2c3 exceeds max_data_size in charge with data_size 1117
# Cycle 86 for cell b2c3 exceeds max_data_size in charge with data_size 1131
# Cycle 87 for cell b2c3 exceeds max_data_size in charge with data_size 1128
# Cycle 88 for cell b2c3 exceeds max_data_size in charge with data_size 1122
# Cycle 89 for cell b2c3 exceeds max_data_size in charge with data_size 1045
# Cycle 90 for cell b2c3 exceeds max_data_size in charge with data_size 1053
# Cycle 91 for cell b2c3 exceeds max_data_size in charge with data_size 1030
# Cycle 92 for cell b2c3 exceeds max_data_size in charge with data_size 1180
# Cycle 93 for cell b2c3 exceeds max_data_size in charge with data_size 1281
# Cycle 94 for cell b2c3 exceeds max_data_size in charge with data_size 1175
# Cycle 95 for cell b2c3 exceeds max_data_size in charge with data_size 1142
# Cycle 96 for cell b2c3 exceeds max_data_size in charge with data_size 1101
# Cycle 97 for cell b2c3 exceeds max_data_size in charge with data_size 1109
# Cycle 98 for cell b2c3 exceeds max_data_size in charge with data_size 1187
# Cycle 99 for cell b2c3 exceeds max_data_size in charge with data_size 1095
# Cycle 100 for cell b2c3 exceeds max_data_size in charge with data_size 1160
# Cycle 2 for cell b2c6 exceeds max_data_size in charge with data_size 1800
# Cycle 3 for cell b2c6 exceeds max_data_size in charge with data_size 1852
# Cycle 4 for cell b2c6 exceeds max_data_size in charge with data_size 2188
# Cycle 5 for cell b2c6 exceeds max_data_size in charge with data_size 1616
# Cycle 6 for cell b2c6 exceeds max_data_size in charge with data_size 1458
# Cycle 7 for cell b2c6 exceeds max_data_size in charge with data_size 1404
# Cycle 8 for cell b2c6 exceeds max_data_size in charge with data_size 1069
# Cycle 9 for cell b2c6 exceeds max_data_size in charge with data_size 1036
# Cycle 10 for cell b2c6 exceeds max_data_size in charge with data_size 1021
# Cycle 15 for cell b2c6 exceeds max_data_size in charge with data_size 1231
# Cycle 18 for cell b2c6 exceeds max_data_size in charge with data_size 1632
# Cycle 19 for cell b2c6 exceeds max_data_size in charge with data_size 1314
# Cycle 20 for cell b2c6 exceeds max_data_size in charge with data_size 1196
# Cycle 23 for cell b2c6 exceeds max_data_size in charge with data_size 1297
# Cycle 24 for cell b2c6 exceeds max_data_size in charge with data_size 1097
# Cycle 26 for cell b2c6 exceeds max_data_size in charge with data_size 1028
# Cycle 27 for cell b2c6 exceeds max_data_size in charge with data_size 1004
# Cycle 28 for cell b2c6 exceeds max_data_size in charge with data_size 1132
# Cycle 33 for cell b2c6 exceeds max_data_size in charge with data_size 1221
# Cycle 34 for cell b2c6 exceeds max_data_size in charge with data_size 1077
# Cycle 35 for cell b2c6 exceeds max_data_size in charge with data_size 1036
# Cycle 36 for cell b2c6 exceeds max_data_size in charge with data_size 1061
# Cycle 48 for cell b2c6 exceeds max_data_size in charge with data_size 1106
# Cycle 51 for cell b2c6 exceeds max_data_size in charge with data_size 1133
# Cycle 58 for cell b2c6 exceeds max_data_size in charge with data_size 1018
# Cycle 59 for cell b2c6 exceeds max_data_size in charge with data_size 1107
# Cycle 63 for cell b2c6 exceeds max_data_size in charge with data_size 1073
# Cycle 67 for cell b2c6 exceeds max_data_size in charge with data_size 1221
# Cycle 68 for cell b2c6 exceeds max_data_size in charge with data_size 1042
# Cycle 76 for cell b2c6 exceeds max_data_size in charge with data_size 1026
# Cycle 78 for cell b2c6 exceeds max_data_size in charge with data_size 1001
# Cycle 79 for cell b2c6 exceeds max_data_size in charge with data_size 1033
# Cycle 81 for cell b2c6 exceeds max_data_size in charge with data_size 1204
# Cycle 83 for cell b2c6 exceeds max_data_size in charge with data_size 1009
# Cycle 86 for cell b2c6 exceeds max_data_size in charge with data_size 1010
# Cycle 89 for cell b2c6 exceeds max_data_size in charge with data_size 1063
# Cycle 90 for cell b2c6 exceeds max_data_size in charge with data_size 1034
# Cycle 15 for cell b2c41 exceeds max_data_size in charge with data_size 1013
# Cycle 40 for cell b2c41 exceeds max_data_size in charge with data_size 1043
# Cycle 41 for cell b2c41 exceeds max_data_size in charge with data_size 1012
# Cycle 42 for cell b2c41 exceeds max_data_size in charge with data_size 1073
# Cycle 44 for cell b2c41 exceeds max_data_size in charge with data_size 1015
# Cycle 51 for cell b2c41 exceeds max_data_size in charge with data_size 1041
# Cycle 62 for cell b2c41 exceeds max_data_size in charge with data_size 1034
# Cycle 64 for cell b2c41 exceeds max_data_size in charge with data_size 1035
# Cycle 65 for cell b2c41 exceeds max_data_size in charge with data_size 1070
# Cycle 66 for cell b2c41 exceeds max_data_size in charge with data_size 1074
# Cycle 67 for cell b2c41 exceeds max_data_size in charge with data_size 1063
# Cycle 68 for cell b2c41 exceeds max_data_size in charge with data_size 1071
# Cycle 75 for cell b2c41 exceeds max_data_size in charge with data_size 1112
# Cycle 76 for cell b2c41 exceeds max_data_size in charge with data_size 1153
# Cycle 77 for cell b2c41 exceeds max_data_size in charge with data_size 1064
# Cycle 85 for cell b2c41 exceeds max_data_size in charge with data_size 1208
# Cycle 86 for cell b2c41 exceeds max_data_size in charge with data_size 1218
# Cycle 87 for cell b2c41 exceeds max_data_size in charge with data_size 1379
# Cycle 88 for cell b2c41 exceeds max_data_size in charge with data_size 1282
# Cycle 89 for cell b2c41 exceeds max_data_size in charge with data_size 1341
# Cycle 90 for cell b2c41 exceeds max_data_size in charge with data_size 1216
# Cycle 91 for cell b2c41 exceeds max_data_size in charge with data_size 1180
# Cycle 92 for cell b2c41 exceeds max_data_size in charge with data_size 1164
# Cycle 93 for cell b2c41 exceeds max_data_size in charge with data_size 1108
# Cycle 99 for cell b2c41 exceeds max_data_size in charge with data_size 1050
# Cycle 100 for cell b2c41 exceeds max_data_size in charge with data_size 1123
# Cycle 2 for cell b2c47 exceeds max_data_size in charge with data_size 1116
# Cycle 3 for cell b2c47 exceeds max_data_size in charge with data_size 1285
# Cycle 4 for cell b2c47 exceeds max_data_size in charge with data_size 1247
# Cycle 5 for cell b2c47 exceeds max_data_size in charge with data_size 1245
# Cycle 6 for cell b2c47 exceeds max_data_size in charge with data_size 1097
# Cycle 12 for cell b2c47 exceeds max_data_size in charge with data_size 1049
# Cycle 13 for cell b2c47 exceeds max_data_size in charge with data_size 1292
# Cycle 14 for cell b2c47 exceeds max_data_size in charge with data_size 1284
# Cycle 15 for cell b2c47 exceeds max_data_size in charge with data_size 1251
# Cycle 16 for cell b2c47 exceeds max_data_size in charge with data_size 1245
# Cycle 17 for cell b2c47 exceeds max_data_size in charge with data_size 1163
# Cycle 18 for cell b2c47 exceeds max_data_size in charge with data_size 1044
# Cycle 19 for cell b2c47 exceeds max_data_size in charge with data_size 1107
# Cycle 20 for cell b2c47 exceeds max_data_size in charge with data_size 1058
# Cycle 21 for cell b2c47 exceeds max_data_size in charge with data_size 1028
# Cycle 22 for cell b2c47 exceeds max_data_size in charge with data_size 1003
# Cycle 52 for cell b2c47 exceeds max_data_size in charge with data_size 1024
# Cycle 53 for cell b2c47 exceeds max_data_size in charge with data_size 1113
# Cycle 54 for cell b2c47 exceeds max_data_size in charge with data_size 1081
# Cycle 77 for cell b2c47 exceeds max_data_size in charge with data_size 1033
# Cycle 78 for cell b2c47 exceeds max_data_size in charge with data_size 1054
# Cycle 87 for cell b2c47 exceeds max_data_size in charge with data_size 1076
# Cycle 88 for cell b2c47 exceeds max_data_size in charge with data_size 1143
# Cycle 89 for cell b2c47 exceeds max_data_size in charge with data_size 1191
# Cycle 90 for cell b2c47 exceeds max_data_size in charge with data_size 1145
# Cycle 91 for cell b2c47 exceeds max_data_size in charge with data_size 1105
# Cycle 92 for cell b2c47 exceeds max_data_size in charge with data_size 1121
# Cycle 93 for cell b2c47 exceeds max_data_size in charge with data_size 1117
# Cycle 94 for cell b2c47 exceeds max_data_size in charge with data_size 1099
# Cycle 95 for cell b2c47 exceeds max_data_size in charge with data_size 1091
# remove cycle 15 from time for cell b3c17
# Cycles cleaned for cells with IDs: b1c7, b1c5, b1c3, b1c20, b1c2, b1c6, b1c11, b3c17, b1c1, b1c4, b1c0, b1c14, b1c16, b1c18, b1c21, b1c15

# %% [markdown]
# Reaming the abnormal cells to see DNN performance and fair comparison. However, It is not practical.

# %%
print(eol.shape, cycle_data_dis.shape, cycle_data_ch.shape)
# Out:
# (124, 1) (124, 100, 5, 500) (124, 100, 5, 500)

# %%
np.save(eol_path',eol)
np.save(cycle_data_dis_path,cycle_data_dis)
np.save(cycle_data_ch_path,cycle_data_ch)

# %% [markdown]
# ## generation of statistical features

# %%
cycle_sum = cl.getdata_from_summary(bat_dict, 1, 100)

# %%
# convert list to array
cycle_sum=np.array(cycle_sum).reshape(-1,7,100) #(number of cell, features, first n cycle)

# %%
cycle_sum.shape
# Out:
# (124, 7, 100)

# %%
# Extract EOLs from the battery dictionary
EOL = [(key, int(value['cycle_life'][0][0])) for key, value in bat_dict.items()]
battery_ids = [entry[0] for entry in EOL]
EOL_values = [entry[1] for entry in EOL]

# %%
human_data = cl.get_human_data(bat_dict, 1, 100)

# %%
human_data = np.array(human_data)

# %%
human_data.shape
# Out:
# (37200, 1000)

# %%
human_data=np.array(human_data).reshape(124,100,3,1000) #(number of cell, first n cycle, features, time-series data)

# %%
human_data.shape
# Out:
# (124, 100, 3, 1000)

# %%
new_cycle_sum = cl.gen_statistical_data(cycle_sum, human_data, cycle_data_ch, cycle_data_dis)

# %%
new_cycle_sum.shape
# Out:
# (124, 14, 100)

# %%
np.save(new_cycle_sum_path,new_cycle_sum)
